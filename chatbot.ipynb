# %% [markdown]
# ## Building A Chatbot
#
# design and implement an LLM-powered chatbot. This chatbot will be able to have a conversation and remember previous interactions.

# %%
import os
from dotenv import load_dotenv
load_dotenv() #loading all the environment variables

groq_api_key = os.getenv("GROQ_API_KEY")
# groq_api_key

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="gemma2-9b-it", groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x703f2047d950>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x703f2048c5d0>, model_name='gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="My name is sid. I am from Nepal. I'm a datascience Student at VIT vellore university !")])
# Out:
# AIMessage(content="That's great, Sid! It's awesome that you're studying Data Science at VIT Vellore University. \n\nNepal is a beautiful country with a rich culture.  What brought you to study in India? \n\nAre you enjoying your time at VIT? Do you have a favorite area of Data Science you're learning about? \n\nI'd love to hear more about your journey!\n", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 32, 'total_tokens': 118, 'completion_time': 0.156363636, 'prompt_time': 0.002362076, 'queue_time': 0.229887423, 'total_time': 0.158725712}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run-238ce828-30a8-4c8f-a969-934c4756c352-0', usage_metadata={'input_tokens': 32, 'output_tokens': 86, 'total_tokens': 118})

# %%
from langchain_core.messages import AIMessage
model.invoke([
    HumanMessage(content="My name is sid. I am from Nepal. I'm a datascience Student at VIT vellore university !"),
    AIMessage(content="That's great, Sid! It's awesome that you're studying Data Science at VIT Vellore University. \n\nNepal is a beautiful country with a rich culture.  What brought you to study in India? \n\nAre you enjoying your time at VIT? Do you have a favorite area of Data Science you're learning about? \n\nI'd love to hear more about your journey!\n"),
    HumanMessage(content="Hey, What is my name?  and where and what do i study ?")
])
# Out:
# AIMessage(content="You said your name is Sid and you are a Data Science student at VIT Vellore University in India!  😊  \n\nDo you remember anything else about yourself that you'd like to share?  Perhaps your favorite subject in Data Science or something interesting you're working on? \n", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 142, 'total_tokens': 203, 'completion_time': 0.110909091, 'prompt_time': 0.007171749, 'queue_time': 0.23497902099999998, 'total_time': 0.11808084}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run-921934ac-a471-46d2-a7ac-5495fe61325f-0', usage_metadata={'input_tokens': 142, 'output_tokens': 61, 'total_tokens': 203})

# %%
## Working with Message History !!
